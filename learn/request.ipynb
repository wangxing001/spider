# %% [markdown]
# # requests

# %% [markdown]
# ## example
# * status_code
# * url
# * text
# * headers
# * cookies
# * content

# %%
import requests

response = requests.get("http://www.baidu.com/")
# help(requests.get)
print(type(response))
print(response.status_code)
print(response.headers)
print(response.url)
print("********")
print(type(response.text))
# print(response.text.encode("utf-8"))
print(response.cookies)
# print(response.content)
# Out:
# <class 'requests.models.Response'>
# 200
# {'Cache-Control': 'private, no-cache, no-store, proxy-revalidate, no-transform', 'Connection': 'Keep-Alive', 'Content-Encoding': 'gzip', 'Content-Type': 'text/html', 'Date': 'Fri, 15 Feb 2019 11:38:27 GMT', 'Last-Modified': 'Mon, 23 Jan 2017 13:27:32 GMT', 'Pragma': 'no-cache', 'Server': 'bfe/1.0.8.18', 'Set-Cookie': 'BDORZ=27315; max-age=86400; domain=.baidu.com; path=/', 'Transfer-Encoding': 'chunked'}
# http://www.baidu.com/
# ********
# <class 'str'>
# <RequestsCookieJar[<Cookie BDORZ=27315 for .baidu.com/>]>

# %% [markdown]
# ## all kinds of request ways
#
# ## test website  <h2><a href="http://httpbin.org">httpbin</a></h2>

# %%
import requests
# requests.post('http://httpbin.org/post')
# requests.put('http://www.baidu.com/put')
# requests.delete("http://httpbin.org/delete")
requests.head("http://www.baidu.com/get")
# requests.options("http://httpbin.org/get")
# Out:
# <Response [302]>

# %% [markdown]
# ## 基本get请求

# %% [markdown]
# ### 基本写法
# <font color="red">args </font><br />
# <font color="red">headers </font><br />
# <font color="red">origin </font><br />
# <font color="red">url </font><br />

# %%
import requests

response = requests.get("http://httpbin.org/get")
print(response.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.14.2"
#   },
#   "origin": "123.150.255.195",
#   "url": "http://httpbin.org/get"
# }

# %% [markdown]
# ### 带参数的get请求

# %%
import requests
response = requests.get("http://httpbin.org/get?name=wang&age=11")
print(response.text)
# Out:
# {
#   "args": {
#     "age": "11",
#     "name": "wang"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.14.2"
#   },
#   "origin": "202.113.76.93",
#   "url": "http://httpbin.org/get?name=wang&age=11"
# }

# %% [markdown]
# ### 传参方式

# %%
import requests

data = {
    'name':"wang",
    'age':14
}
response = requests.get("http://httpbin.org/get",params=data)
print(response.text)
print(response.url)
# print(help(requests.get))
# Out:
# {
#   "args": {
#     "age": "14",
#     "name": "wang"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.14.2"
#   },
#   "origin": "221.238.82.195, 221.238.82.195",
#   "url": "https://httpbin.org/get?name=wang&age=14"
# }
#
# http://httpbin.org/get?name=wang&age=14

# %% [markdown]
# ### 解析json

# %%
import requests
import json

response = requests.get("http://httpbin.org/get")
print(type(response.text))
print(response.json())
print("\n")
print(json.loads(response.text))
print(type(response.json()))
# Out:
# <class 'str'>
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Connection': 'close', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.14.2'}, 'origin': '123.150.255.195', 'url': 'http://httpbin.org/get'}
#
#
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Connection': 'close', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.14.2'}, 'origin': '123.150.255.195', 'url': 'http://httpbin.org/get'}
# <class 'dict'>

# %% [markdown]
# ### 获取二进制数据（下载图片或视频的时候）

# %%
import requests

response = requests.get("http://i0.cy.com/xyj_pc/pic/2018/0628/jt1.jpg")
print(type(response.text),type(response.content))
print(response.text)
print("============")
print(response.content)
# Out:
# <class 'str'> <class 'bytes'>
# ...

# %%
import requests

response = requests.get("http://i0.cy.com/xyj_pc/pic/2018/0628/jt1.jpg")
with open('D:/Spider/test/test1.png',"wb") as f:
    f.write(response.content)
    f.close()

# %% [markdown]
# ### add headers(不加上可能被禁止访问)

# %%
import requests

response = requests.get("https://www.zhihu.com/explore")
print(response.text)
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
import requests

headers = {
   "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36 "
}
response = requests.get("https://www.zhihu.com/explore",headers=headers)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="renderer" content="webkit" />
# <meta http-equiv="X-ZA-Response-Id" content="f523a4321a8e456e79fb61c3df12193">
#
# <meta http-equiv="X-ZA-Experiment" content="default:None,ge3:ge3_9,ge2:ge2_1,nwebQAGrowth:experiment,is_office:false,nweb_growth_people:default,app_store_rate_dialog:close,nweb_search_suggest:default,live_store:ls_a2_b2_c1_f2,nweb_search:nweb_search_heifetz,search_hybrid_tabs:pin-3#album-7,new_live_feed_mediacard:new,hybrid_zhmore_video:yes,ad_r:a,growth_search:s2,qaweb_related_readings_content_control:close,android_pass_through_push:all,android_search_tab_style:search_tab_style_b,android_db_recommend_action:open,android_db_feed_hash_tag_style:button,is_new_noti_panel:no">
# <title>发现 - 知乎</title>
#
# ...

# %% [markdown]
# ## 基本POST请求

# %%
import requests

data = {
    'name':"wang",
    'age':"222",
    'sex':'man'
}
response = requests.post("http://httpbin.org/post",data=data)
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "age": "222",
#     "name": "wang",
#     "sex": "man"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "25",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.14.2"
#   },
#   "json": null,
#   "origin": "202.113.76.93",
#   "url": "http://httpbin.org/post"
# }

# %%
#add headers
import requests

data = {
    'name':"wang",
    'age':"222",
    'sex':'man'
}
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"
}
response = requests.post("http://httpbin.org/post",data=data,headers=headers)
print(response.json())
# help(requests.post)
# Out:
# {'args': {}, 'data': '', 'files': {}, 'form': {'age': '222', 'name': 'wang', 'sex': 'man'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Connection': 'close', 'Content-Length': '25', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36'}, 'json': None, 'origin': '221.238.82.195', 'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 响应

# %% [markdown]
# ### response属性

# %%
import requests

response = requests.get("http://zhihu.com")
print("[1]",type(response.status_code),response.status_code)
print("[2]",type(response.headers),response.headers)
print("[3]",type(response.cookies),response.cookies)
print("[4]",type(response.url),response.url)
print("[5]",type(response.history),response.history)
# Out:
# [1] <class 'int'> 400
# [2] <class 'requests.structures.CaseInsensitiveDict'> {'Date': 'Mon, 28 Jan 2019 09:26:29 GMT', 'Content-Type': 'text/html', 'Content-Length': '170', 'Connection': 'keep-alive', 'Set-Cookie': 'tgw_l7_route=f2979fdd289e2265b2f12e4f4a478330; Expires=Mon, 28-Jan-2019 09:41:24 GMT; Path=/', 'Server': 'ZWS', 'Vary': 'Accept-Encoding'}
# [3] <class 'requests.cookies.RequestsCookieJar'> <RequestsCookieJar[<Cookie tgw_l7_route=f2979fdd289e2265b2f12e4f4a478330 for zhihu.com/>]>
# [4] <class 'str'> http://zhihu.com/
# [5] <class 'list'> []

# %% [markdown]
# ### status code

# %%
import requests

response = requests.get("http://www.jianshu.com/")
# exit() if not response.status_code == requests.codes.not_found else print('Reuqest Successfully')
print(requests.codes.name)
# Out:
# status_codes

# %%
import requests

response = requests.get("http://www.jianshu.com")
exit() if not response.status_code == 30 else print('Reuqest Successfully')

# %%
100: ('continue',),
101: ('switching_protocols',),
102: ('processing',),
103: ('checkpoint',),
122: ('uri_too_long', 'request_uri_too_long'),
200: ('ok', 'okay', 'all_ok', 'all_okay', 'all_good', '\\o/', '✓'),
201: ('created',),
202: ('accepted',),
203: ('non_authoritative_info', 'non_authoritative_information'),
204: ('no_content',),
205: ('reset_content', 'reset'),
206: ('partial_content', 'partial'),
207: ('multi_status', 'multiple_status', 'multi_stati', 'multiple_stati'),
208: ('already_reported',),
226: ('im_used',),

# Redirection.
300: ('multiple_choices',),
301: ('moved_permanently', 'moved', '\\o-'),
302: ('found',),
303: ('see_other', 'other'),
304: ('not_modified',),
305: ('use_proxy',),
306: ('switch_proxy',),
307: ('temporary_redirect', 'temporary_moved', 'temporary'),
308: ('permanent_redirect',
      'resume_incomplete', 'resume',), # These 2 to be removed in 3.0

# Client Error.
400: ('bad_request', 'bad'),
401: ('unauthorized',),
402: ('payment_required', 'payment'),
403: ('forbidden',),
404: ('not_found', '-o-'),
405: ('method_not_allowed', 'not_allowed'),
406: ('not_acceptable',),
407: ('proxy_authentication_required', 'proxy_auth', 'proxy_authentication'),
408: ('request_timeout', 'timeout'),
409: ('conflict',),
410: ('gone',),
411: ('length_required',),
412: ('precondition_failed', 'precondition'),
413: ('request_entity_too_large',),
414: ('request_uri_too_large',),
415: ('unsupported_media_type', 'unsupported_media', 'media_type'),
416: ('requested_range_not_satisfiable', 'requested_range', 'range_not_satisfiable'),
417: ('expectation_failed',),
418: ('im_a_teapot', 'teapot', 'i_am_a_teapot'),
421: ('misdirected_request',),
422: ('unprocessable_entity', 'unprocessable'),
423: ('locked',),
424: ('failed_dependency', 'dependency'),
425: ('unordered_collection', 'unordered'),
426: ('upgrade_required', 'upgrade'),
428: ('precondition_required', 'precondition'),
429: ('too_many_requests', 'too_many'),
431: ('header_fields_too_large', 'fields_too_large'),
444: ('no_response', 'none'),
449: ('retry_with', 'retry'),
450: ('blocked_by_windows_parental_controls', 'parental_controls'),
451: ('unavailable_for_legal_reasons', 'legal_reasons'),
499: ('client_closed_request',),

# Server Error.
500: ('internal_server_error', 'server_error', '/o\\', '✗'),
501: ('not_implemented',),
502: ('bad_gateway',),
503: ('service_unavailable', 'unavailable'),
504: ('gateway_timeout',),
505: ('http_version_not_supported', 'http_version'),
506: ('variant_also_negotiates',),
507: ('insufficient_storage',),
509: ('bandwidth_limit_exceeded', 'bandwidth'),
510: ('not_extended',),
511: ('network_authentication_required', 'network_auth', 'network_authentication'),

# %% [markdown]
# ## 高级操作

# %% [markdown]
# ### 文件上传

# %%
import requests

files = {"file":open('test1.png','rb')}
response = requests.post("http://httpbin.org/post",files=files)
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {
#     "file": "data:application/octet-stream;base64,..."
#   },
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "92948",
#     "Content-Type": "multipart/form-data; boundary=084ff497f9ab45b2ad25e9338c23a821",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.14.2"
#   },
#   "json": null,
#   "origin": "202.113.76.93",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# ### 获取cookies

# %%
import requests

response = requests.get("http://www.baidu.com")
print(type(response.cookies))
print(response.cookies.keys)
print("======")
for key,value in response.cookies.items(): #字典的形式
    print(key+'='+ value)
# Out:
# <class 'requests.cookies.RequestsCookieJar'>
# <bound method RequestsCookieJar.keys of <RequestsCookieJar[Cookie(version=0, name='BDORZ', value='27315', port=None, port_specified=False, domain='.baidu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1550317513, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>>
# ...
# BDORZ=27315

# %% [markdown]
# ### 会话维持

# %%
#模拟登陆
import requests

requests.get("http://httpbin.org/cookies/set/number/123456")
response = requests.get("http://httpbin.org/cookies")
print(response.text)
# Out:
# {
#   "cookies": {}
# }

# %%
import requests

s = requests.Session()
s.get("http://httpbin.org/cookies/set/number/123456789")
response = s.get("http://httpbin.org/cookies")
print(response.text)
# Out:
# {
#   "cookies": {
#     "number": "123456789"
#   }
# }

# %% [markdown]
# ### 证书验证

# %%
import requests

response = requests.get('http://www.12306.com',verify=False)
print(response.status_code)
# Out:
# 200

# %%
import requests

from requests.packages import urllib3
urllib3.disable_warnings()
response = requests.get('http://www.12306.com',verify=False)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# ### 代理设置

# %% [markdown]
# #### http 代理

# %%
import requests
proxies = {
    "http":'121.61.3.143：9999'
}
response = requests.get('https://www.taobao.com',proxies=proxies)
print(response.status_code)
# print(response.text)
# Out:
# 200

# %% [markdown]
# #### socket代理
# pip install 'requests[socks]'

# %%
import requests

proxies = {
    "http":"socks5://ip"
    "https":"socks5://ip"
}
response = requests.get("http://www.taobao.com",proxies=proxies)
print(response.status_code)

# %% [markdown]
# ### 超时设置

# %%
import requests
from requests.exceptions import ReadTimeout,Timeout

try:
    response = requests.get("http://www.python.org/",timeout=0.05)
    print(response.status_code)
except ReadTimeout:
    print("Time Out!")
except Timeout:
    print("out")
finally :
    print("successfully!")
# Out:
# out
# successfully!

# %% [markdown]
# ### 认证设置

# %%
#必须先登录，才能进入网站
import requests
from requests.auth import HTTPBasicAuth

r = requests.get("http://gmis.tjut.edu.cn/pyxx/login.aspx",auth=HTTPBasicAuth("user","password"))
print(r.status_code)
# Out:
# 200

# %%
import requests

r = response.get("http://www.baidu.com",auth=("user","password"))
print(r.status_code)

# %% [markdown]
# ### 异常处理 <a href="http://www.python-requests.org/en/master/api/#exceptions">exception官方文档</a>

# %%
import requests
from requests.exceptions import ReadTimeout,HTTPError,RequestException,ConnectionError

try:
    response = requests.get("http://www.taobao.com",timeout=0.01)
    print(response.status_code)
except ReadTimeout:
    print("timeout!")
except HTTPError:
    print("http error")
except ConnectionError:
    print("connection error")
except RequestException:
    print("error")
# Out:
# connection error
